# %%
# Install a pip comtradeapicall package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install --upgrade comtradeapicall

# %%
# Install a pip pandas package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install pandas

# %%
import pandas
import requests
import comtradeapicall

# %%
import importlib.metadata
version = importlib.metadata.version("comtradeapicall")
print("comtradeapicall version:", version)
# Out:
# comtradeapicall version: 1.2.2

# %%
# comtrade api subscription key (from comtradedeveloper.un.org)
subscription_key = '<YOUR KEY>'
directory = '<OUTPUT DIR>'  # output directory for downloaded files
proxy_url = '<PROXY URL>'  # optional if you need proxy url

# %%
# set some variables
from datetime import date
from datetime import timedelta
today = date.today()
yesterday = today - timedelta(days=1)
lastweek = today - timedelta(days=7)

# %%
# Call preview final data API to a data frame, max to 500 records, no subscription key required
# This example: Australia imports of commodity code 91 in classic mode in May 2022

# %%
mydf = comtradeapicall.previewFinalData(typeCode='C', freqCode='M', clCode='HS', period='202205',
                                        reporterCode='36', cmdCode='91', flowCode='M', partnerCode=None,
                                        partner2Code=None,
                                        customsCode=None, motCode=None, maxRecords=500, format_output='JSON',
                                        aggregateBy=None, breakdownMode='classic', countOnly=None, includeDesc=True)

# %%
mydf.head(5)
# Out:
#   typeCode freqCode  refPeriodId  refYear  refMonth  period  reporterCode  \
# 0        C        M     20220501     2022         5  202205            36
# 1        C        M     20220501     2022         5  202205            36
# 2        C        M     20220501     2022         5  202205            36
# 3        C        M     20220501     2022         5  202205            36
# 4        C        M     20220501     2022         5  202205            36
#
#   reporterISO reporterDesc flowCode  ... netWgt  isNetWgtEstimated grossWgt  \
# 0         AUS    Australia        M  ...    0.0              False      0.0
# 1         AUS    Australia        M  ...    0.0              False      0.0
# 2         AUS    Australia        M  ...    0.0              False      0.0
# 3         AUS    Australia        M  ...    0.0               True      0.0
# 4         AUS    Australia        M  ...    0.0              False      0.0
#
#   isGrossWgtEstimated      cifvalue      fobvalue  primaryValue  \
# 0               False  6.735064e+07  6.642209e+07  6.735064e+07
# 1               False  8.208810e+02  7.800080e+02  8.208810e+02
# 2               False  2.605931e+05  2.599554e+05  2.605931e+05
# 3               False  2.668635e+04  2.544649e+04  2.668635e+04
# 4               False  7.410397e+03  7.027445e+03  7.410397e+03
#
#   legacyEstimationFlag isReported  isAggregate
# 0                    0      False         True
# 1                    0      False         True
# 2                    0      False         True
# 3                    4      False         True
# 4                    0      False         True
#
# [5 rows x 47 columns]

# %%
# Call preview tariffline data API to a data frame, max to 500 records, no subscription key required
# This example: Australia imports of commodity code started with 90 and 91 from Indonesia in May 2022

# %%
mydf = comtradeapicall.previewTarifflineData(typeCode='C', freqCode='M', clCode='HS', period='202205',
                                             reporterCode='36', cmdCode='91,90', flowCode='M', partnerCode=36,
                                             partner2Code=None,
                                             customsCode=None, motCode=None, maxRecords=500, format_output='JSON',
                                             countOnly=None, includeDesc=True)

# %%
mydf.head(5)
# Out:
#   typeCode freqCode  refPeriodId  period  reporterCode reporterDesc  \
# 0        C        M     20220501  202205            36    Australia
# 1        C        M     20220501  202205            36    Australia
# 2        C        M     20220501  202205            36    Australia
# 3        C        M     20220501  202205            36    Australia
# 4        C        M     20220501  202205            36    Australia
#
#   reporterISO flowCode flowDesc  partnerCode  ... qtyUnitAbbr  qty  \
# 0         AUS        M   Import           36  ...         N/A  0.0
# 1         AUS        M   Import           36  ...         N/A  0.0
# 2         AUS        M   Import           36  ...         N/A  0.0
# 3         AUS        M   Import           36  ...         N/A  0.0
# 4         AUS        M   Import           36  ...         N/A  0.0
#
#    altQtyUnitCode altQtyUnitAbbr altQty netWgt grossWgt       cifvalue  \
# 0              -1            N/A    0.0    0.0      3.0    1118.299108
# 1              -1            N/A    0.0    0.0      2.0    2178.010200
# 2              -1            N/A    0.0    0.0     86.0   28196.674488
# 3              -1            N/A    0.0    0.0      1.0    1041.531036
# 4              -1            N/A    0.0    0.0  93000.0  217240.477676
#
#         fobvalue   primaryValue
# 0    1003.845148    1118.299108
# 1    2112.074000    2178.010200
# 2   26240.047724   28196.674488
# 3     931.569200    1041.531036
# 4  215850.979804  217240.477676
#
# [5 rows x 34 columns]

# %%
# The same preview final call but using proxy_url
mydf = comtradeapicall.previewTarifflineData(typeCode='C', freqCode='M', clCode='HS', period='202205',
                                             reporterCode='36', cmdCode='91,90', flowCode='M', partnerCode=36,
                                             partner2Code=None,
                                             customsCode=None, motCode=None, maxRecords=500, format_output='JSON',
                                             countOnly=None, includeDesc=True, proxy_url=proxy_url)

# %%
# Call get final data API to a data frame, max to 250K records, subscription key required
# This example: Australia imports of commodity codes 90 and 91 from all partners in classic mode in May 2022

# %%
mydf = comtradeapicall.getFinalData(subscription_key, typeCode='C', freqCode='M', clCode='HS', period='202205',
                                    reporterCode='36', cmdCode='91,90', flowCode='M', partnerCode=None,
                                    partner2Code=None,
                                    customsCode=None, motCode=None, maxRecords=2500, format_output='JSON',
                                    aggregateBy=None, breakdownMode='classic', countOnly=None, includeDesc=True)

# %%
mydf.head(5)
# Out:
#   typeCode freqCode  refPeriodId  refYear  refMonth  period  reporterCode  \
# 0        C        M     20220501     2022         5  202205            36
# 1        C        M     20220501     2022         5  202205            36
# 2        C        M     20220501     2022         5  202205            36
# 3        C        M     20220501     2022         5  202205            36
# 4        C        M     20220501     2022         5  202205            36
#
#   reporterISO reporterDesc flowCode  ... netWgt  isNetWgtEstimated grossWgt  \
# 0         AUS    Australia        M  ...    0.0              False      0.0
# 1         AUS    Australia        M  ...    0.0               True      0.0
# 2         AUS    Australia        M  ...    0.0               True      0.0
# 3         AUS    Australia        M  ...    0.0               True      0.0
# 4         AUS    Australia        M  ...    0.0               True      0.0
#
#   isGrossWgtEstimated      cifvalue      fobvalue  primaryValue  \
# 0               False  3.024066e+05  2.547313e+05  3.024066e+05
# 1               False  8.900632e+03  8.692718e+03  8.900632e+03
# 2               False  2.913730e+07  2.712739e+07  2.913730e+07
# 3               False  1.091258e+07  1.015719e+07  1.091258e+07
# 4               False  1.601507e+04  1.571131e+04  1.601507e+04
#
#   legacyEstimationFlag isReported  isAggregate
# 0                    0      False         True
# 1                    4      False         True
# 2                    4      False         True
# 3                    4      False         True
# 4                    4      False         True
#
# [5 rows x 47 columns]

# %%
# Call get tariffline data API to a data frame, max to 250K records, subscription key required
# This example: Australia imports of commodity code started with 90 and 91 from Indonesia in May 2022

# %%
mydf = comtradeapicall.getTarifflineData(subscription_key, typeCode='C', freqCode='M', clCode='HS', period='202205',
                                         reporterCode='36', cmdCode='91,90', flowCode='M', partnerCode=36,
                                         partner2Code=None,
                                         customsCode=None, motCode=None, maxRecords=2500, format_output='JSON',
                                         countOnly=None, includeDesc=True)

# %%
mydf.head(5)
# Out:
#   typeCode freqCode  refPeriodId  period  reporterCode reporterDesc  \
# 0        C        M     20220501  202205            36    Australia
# 1        C        M     20220501  202205            36    Australia
# 2        C        M     20220501  202205            36    Australia
# 3        C        M     20220501  202205            36    Australia
# 4        C        M     20220501  202205            36    Australia
#
#   reporterISO flowCode flowDesc  partnerCode  ... qtyUnitAbbr  qty  \
# 0         AUS        M   Import           36  ...         N/A  0.0
# 1         AUS        M   Import           36  ...         N/A  0.0
# 2         AUS        M   Import           36  ...         N/A  0.0
# 3         AUS        M   Import           36  ...         N/A  0.0
# 4         AUS        M   Import           36  ...         N/A  0.0
#
#    altQtyUnitCode altQtyUnitAbbr altQty netWgt grossWgt     cifvalue  \
# 0              -1            N/A    0.0    0.0     24.0  2643.138964
# 1              -1            N/A    0.0    0.0      0.0  1378.122996
# 2              -1            N/A    0.0    0.0      7.7  7291.986612
# 3              -1            N/A    0.0    0.0      3.8  3318.812240
# 4              -1            N/A    0.0    0.0    128.8  7020.139064
#
#       fobvalue primaryValue
# 0  2452.269532  2643.138964
# 1  1345.429924  1378.122996
# 2  6990.838004  7291.986612
# 3  3151.313136  3318.812240
# 4  4936.400000  7020.139064
#
# [5 rows x 34 columns]

# %%
# Call bulk download final file(s) API to output dir, (premium) subscription key required
# This example: Download monthly France final data of Jan-2000

# %%
comtradeapicall.bulkDownloadFinalFile(subscription_key, directory, typeCode='C', freqCode='M', clCode='HS',
                                      period='200001', reporterCode=251, decompress=True)
# Out:
# COMTRADE-FINAL-CM251200001H1[2022-09-04] downloaded
# Total of 1 file(s) downloaded

# %%
# Call bulk download final file(s) API to output dir, (premium) subscription key required
# This example: Download monthly France final classic data of Jan-2000

# %%
comtradeapicall.bulkDownloadFinalClassicFile(subscription_key, directory, typeCode='C', freqCode='M', clCode='HS',
                                             period='200001', reporterCode=251, decompress=True)
# Out:
# COMTRADE-FINALCLASSIC-CM251200001H1[2022-09-04] downloaded
# Total of 1 file(s) downloaded

# %%
# Call bulk download tariff data file(s) to output dir, (premium) subscription key required
# This example: Download monthly France tariffline data of Jan-2000

# %%
comtradeapicall.bulkDownloadTarifflineFile(subscription_key, directory, typeCode='C', freqCode='M', clCode='HS',
                                           period='200001,200002,200003', reporterCode=504, decompress=True)
# Out:
# COMTRADE-TARIFFLINE-CM504200003H1[2023-01-03] downloaded
# COMTRADE-TARIFFLINE-CM504200001H1[2022-12-09] downloaded
# COMTRADE-TARIFFLINE-CM504200002H1[2023-01-03] downloaded
# Total of 3 file(s) downloaded

# %%
# Call bulk download tariff data file(s) to output dir, (premium) subscription key required
# This example: Download annual Morocco  data of 2010

# %%
comtradeapicall.bulkDownloadTarifflineFile(subscription_key, directory, typeCode='C', freqCode='A', clCode='HS',
                                           period='2010', reporterCode=504, decompress=True)
# Out:
# COMTRADE-TARIFFLINE-CA5042010H2[2021-12-09] downloaded
# Total of 1 file(s) downloaded

# %%
# Call data availability for annual HS in 2021

# %%
mydf = comtradeapicall.getFinalDataAvailability(subscription_key, typeCode='C', freqCode='A', clCode='HS',
                                                period='2021', reporterCode=None)
mydf.head(5)
# Out:
#          datasetCode typeCode freqCode  period  reporterCode reporterISO  \
# 0  20024202101182100        C        A    2021            24         AGO
# 1  20031202101182100        C        A    2021            31         AZE
# 2  20032202101182100        C        A    2021            32         ARG
# 3  20036202101182100        C        A    2021            36         AUS
# 4  20040202101182100        C        A    2021            40         AUT
#
#   reporterDesc classificationCode classificationSearchCode  \
# 0       Angola                 H5                       HS
# 1   Azerbaijan                 H5                       HS
# 2    Argentina                 H5                       HS
# 3    Australia                 H5                       HS
# 4      Austria                 H5                       HS
#
#    isOriginalClassification  isExtendedFlowCode  isExtendedPartnerCode  \
# 0                      True               False                   True
# 1                      True                True                   True
# 2                      True                True                   True
# 3                      True                True                   True
# 4                      True               False                   True
#
#    isExtendedPartner2Code  isExtendedCmdCode  isExtendedCustomsCode  \
# 0                   False               True                  False
# 1                    True               True                   True
# 2                    True               True                  False
# 3                   False               True                  False
# 4                   False               True                  False
#
#    isExtendedMotCode  totalRecords  datasetChecksum  \
# 0              False        112758      -1349955130
# 1               True       1631459       1375342973
# 2              False        416716      -1541907476
# 3               True        644604      -1567412700
# 4              False        440139      -1077957935
#
#                  firstReleased                 lastReleased
# 0  2022-10-06T10:53:32.8266667  2022-10-06T10:53:32.8266667
# 1  2022-03-29T22:50:18.8066667  2022-05-03T19:12:39.8333333
# 2  2022-06-14T19:12:34.7433333  2022-06-14T19:12:34.7433333
# 3  2022-03-30T01:44:28.7033333  2022-03-30T01:44:28.7033333
# 4        2022-05-27T04:12:54.5        2022-05-27T04:12:54.5

# %%
# Call tariffline data availability for monthly HS in Jun-2022

# %%
mydf = comtradeapicall.getTarifflineDataAvailability(subscription_key, typeCode='C', freqCode='M', clCode='HS',
                                                     period='202206', reporterCode=None)
mydf.head(5)
# Out:
#          datasetCode typeCode freqCode  period  reporterCode reporterISO  \
# 0  30031202206202100        C        M  202206            31         AZE
# 1  30032202206182100        C        M  202206            32         ARG
# 2  30036202206202100        C        M  202206            36         AUS
# 3  30051202206202100        C        M  202206            51         ARM
# 4  30052202206182100        C        M  202206            52         BRB
#
#   classificationCode  isOriginalClassification  isExtendedFlowCode  \
# 0                 H6                      True               False
# 1                 H5                      True               False
# 2                 H6                      True               False
# 3                 H6                      True                True
# 4                 H5                      True                True
#
#    isExtendedPartnerCode  isExtendedPartner2Code  isExtendedCmdCode  \
# 0                   True                    True               True
# 1                   True                    True               True
# 2                   True                   False               True
# 3                   True                    True               True
# 4                   True                   False               True
#
#    isExtendedCustomsCode  isExtendedMotCode  totalRecords  datasetChecksum  \
# 0                   True               True         19183      -1838571256
# 1                  False              False         61039       1200220404
# 2                  False               True        268223      -1343158038
# 3                  False               True         44956       1878972458
# 4                  False              False          9961       -295889979
#
#    lengthCmdCode                firstReleased                 lastReleased
# 0              6       2022-11-30T20:27:51.62       2022-11-30T20:27:51.62
# 1              8  2022-09-29T18:08:32.9033333  2022-09-29T18:08:32.9033333
# 2              6  2022-08-22T00:14:58.7233333  2022-12-09T02:21:57.7033333
# 3             10  2022-08-27T01:31:00.2566667       2022-09-21T05:12:06.67
# 4             11       2022-08-23T18:30:05.99       2022-08-23T18:30:05.99

# %%
# Call bulk download tariff data file(s) to output dir, (premium) subscription key required
# This example: Download HS annual data released since  yesterday

# %%
from datetime import date
from datetime import timedelta
yesterday = date.today() - timedelta(days=1)
comtradeapicall.bulkDownloadFinalFileDateRange(subscription_key, directory, typeCode='C', freqCode='A',
                                               clCode='HS',
                                               period=None, reporterCode=None, decompress=False,
                                               publishedDateFrom=yesterday, publishedDateTo=None)
# Out:
# No data available based on the selection criteria

# %%
# download reporter code 320 released from yesterday  using the classic layout (brokendown by products by partners only)

# %%
comtradeapicall.bulkDownloadFinalClassicFile(subscription_key, directory, typeCode='C', freqCode='A',
                                             clCode='HS',
                                             period=None, reporterCode=320, decompress=False,
                                             publishedDateFrom=yesterday, publishedDateTo=None)
# Out:
# COMTRADE-FINALCLASSIC-CA3202023H6[2024-03-19] downloaded
# Total of 1 file(s) downloaded

# %%
# Call bulk download tariff data file(s) to output dir, (premium) subscription key required
# This example: Download HS monthly tariffline data released since  yesterday

# %%
comtradeapicall.bulkDownloadTarifflineFileDateRange(subscription_key, directory, typeCode='C', freqCode='M',
                                                    clCode='HS', period=None, reporterCode=None, decompress=False,
                                                    publishedDateFrom=yesterday, publishedDateTo=None)
# Out:
# COMTRADE-TARIFFLINE-CM100202202H6[2023-01-13] downloaded
# COMTRADE-TARIFFLINE-CM100202205H6[2023-01-13] downloaded
# COMTRADE-TARIFFLINE-CM100202203H6[2023-01-13] downloaded
# COMTRADE-TARIFFLINE-CM100202204H6[2023-01-12] downloaded
# COMTRADE-TARIFFLINE-CM703202210H6[2023-01-13] downloaded
# COMTRADE-TARIFFLINE-CM705202201H6[2023-01-14] downloaded
# COMTRADE-TARIFFLINE-CM705202203H6[2023-01-14] downloaded
# COMTRADE-TARIFFLINE-CM705202205H6[2023-01-14] downloaded
# COMTRADE-TARIFFLINE-CM705202202H6[2023-01-14] downloaded
# COMTRADE-TARIFFLINE-CM710202211H6[2023-01-13] downloaded
# COMTRADE-TARIFFLINE-CM710202210H6[2023-01-13] downloaded
# COMTRADE-TARIFFLINE-CM757202211H6[2023-01-13] downloaded
# Total of 12 file(s) downloaded

# %%
# Call final data availability for annual HS in 2021
mydf = comtradeapicall.getFinalDataAvailability(subscription_key, typeCode='C', freqCode='A', clCode='HS',
                                                period='2021', reporterCode=None)
mydf.head(5)
# Out:
#          datasetCode typeCode freqCode  period  reporterCode reporterISO  \
# 0  20024202101182100        C        A    2021            24         AGO
# 1  20031202101182100        C        A    2021            31         AZE
# 2  20032202101182100        C        A    2021            32         ARG
# 3  20036202101182100        C        A    2021            36         AUS
# 4  20040202101182100        C        A    2021            40         AUT
#
#   reporterDesc classificationCode classificationSearchCode  \
# 0       Angola                 H5                       HS
# 1   Azerbaijan                 H5                       HS
# 2    Argentina                 H5                       HS
# 3    Australia                 H5                       HS
# 4      Austria                 H5                       HS
#
#    isOriginalClassification  isExtendedFlowCode  isExtendedPartnerCode  \
# 0                      True               False                   True
# 1                      True                True                   True
# 2                      True                True                   True
# 3                      True                True                   True
# 4                      True               False                   True
#
#    isExtendedPartner2Code  isExtendedCmdCode  isExtendedCustomsCode  \
# 0                   False               True                  False
# 1                    True               True                   True
# 2                    True               True                  False
# 3                   False               True                  False
# 4                   False               True                  False
#
#    isExtendedMotCode  totalRecords  datasetChecksum  \
# 0              False        112758      -1349955130
# 1               True       1631459       1375342973
# 2              False        416716      -1541907476
# 3               True        644604      -1567412700
# 4              False        440139      -1077957935
#
#                  firstReleased                 lastReleased
# 0  2022-10-06T10:53:32.8266667  2022-10-06T10:53:32.8266667
# 1  2022-03-29T22:50:18.8066667  2022-05-03T19:12:39.8333333
# 2  2022-06-14T19:12:34.7433333  2022-06-14T19:12:34.7433333
# 3  2022-03-30T01:44:28.7033333  2022-03-30T01:44:28.7033333
# 4        2022-05-27T04:12:54.5        2022-05-27T04:12:54.5

# %%
# Call tariffline data availability for monthly HS in Jun-2022
mydf = comtradeapicall.getTarifflineDataAvailability(subscription_key, typeCode='C', freqCode='M', clCode='HS',
                                                     period='202206', reporterCode=None)
mydf.head(5)
# Out:
#          datasetCode typeCode freqCode  period  reporterCode reporterISO  \
# 0  30031202206202100        C        M  202206            31         AZE
# 1  30032202206182100        C        M  202206            32         ARG
# 2  30036202206202100        C        M  202206            36         AUS
# 3  30051202206202100        C        M  202206            51         ARM
# 4  30052202206182100        C        M  202206            52         BRB
#
#   classificationCode  isOriginalClassification  isExtendedFlowCode  \
# 0                 H6                      True               False
# 1                 H5                      True               False
# 2                 H6                      True               False
# 3                 H6                      True                True
# 4                 H5                      True                True
#
#    isExtendedPartnerCode  isExtendedPartner2Code  isExtendedCmdCode  \
# 0                   True                    True               True
# 1                   True                    True               True
# 2                   True                   False               True
# 3                   True                    True               True
# 4                   True                   False               True
#
#    isExtendedCustomsCode  isExtendedMotCode  totalRecords  datasetChecksum  \
# 0                   True               True         19183      -1838571256
# 1                  False              False         61039       1200220404
# 2                  False               True        268216        527449718
# 3                  False               True         44956       1878972458
# 4                  False              False          9961       -295889979
#
#    lengthCmdCode                firstReleased                 lastReleased
# 0              6       2022-11-30T20:27:51.62       2022-11-30T20:27:51.62
# 1              8  2022-09-29T18:08:32.9033333  2022-09-29T18:08:32.9033333
# 2              6  2022-08-22T00:14:58.7233333  2023-01-12T02:32:26.3933333
# 3             10  2022-08-27T01:31:00.2566667       2022-09-21T05:12:06.67
# 4             11       2022-08-23T18:30:05.99       2022-08-23T18:30:05.99

# %%
# Call final bulk files data availability for annual S1 in 2021
mydf = comtradeapicall.getFinalDataBulkAvailability(subscription_key, typeCode='C', freqCode='A', clCode='S1',
                                                    period='2021', reporterCode=None)
mydf.head(5)
# Out:
#                                              fileUrl   fileSize  \
# 0  https://comtradeapi.un.org/bulk/v1/file/100/67...    8.48 MB
# 1  https://comtradeapi.un.org/bulk/v1/file/104/24...    2.62 MB
# 2  https://comtradeapi.un.org/bulk/v1/file/108/a7...  329.45 KB
# 3  https://comtradeapi.un.org/bulk/v1/file/112/2c...    2.92 MB
# 4  https://comtradeapi.un.org/bulk/v1/file/116/1d...  432.06 KB
#
#    isOriginalClassification  reporterCode freqCode typeCode  \
# 0                     False           100        A        C
# 1                     False           104        A        C
# 2                     False           108        A        C
# 3                     False           112        A        C
# 4                     False           116        A        C
#
#   classificationCode  refPeriodId  period       publicationDate partitionKey  \
# 0                 S1       202101    2021  2022-11-11T03:45:19Z          100
# 1                 S1       202101    2021  2022-06-01T17:25:36Z          104
# 2                 S1       202101    2021  2022-10-10T16:48:05Z          108
# 3                 S1       202101    2021  2022-04-12T11:29:15Z          112
# 4                 S1       202101    2021  2022-10-17T17:19:27Z          116
#
#                                               rowKey  \
# 0  674d8255f5b11e9d100dc2891449fc6d6fcbc0ce8dd163...
# 1  240e0a06da369367c6719ade395f0fa473460c670372f1...
# 2  a7ed5ad4042ae422faeaa7a0a5449d308a88b1cdeff786...
# 3  2cc87fecc6e0c51d2482babc5804c81f2e0ef579010367...
# 4  1d1e20237d40dbfc9685fcbc41192c8a742ee9fac2a34d...
#
#                            timestamp  \
# 0   2022-11-11T02:45:19.379056+00:00
# 1  2022-06-01T15:25:36.7326177+00:00
# 2   2022-10-10T14:48:06.004356+00:00
# 3  2022-04-12T09:29:15.3544847+00:00
# 4  2022-10-17T15:19:27.7646758+00:00
#
#                                              eTag
# 0   W/"datetime'2022-11-11T02%3A45%3A19.379056Z'"
# 1  W/"datetime'2022-06-01T15%3A25%3A36.7326177Z'"
# 2   W/"datetime'2022-10-10T14%3A48%3A06.004356Z'"
# 3  W/"datetime'2022-04-12T09%3A29%3A15.3544847Z'"
# 4  W/"datetime'2022-10-17T15%3A19%3A27.7646758Z'"

# %%
# Call tariffline bulk files data availability for monthly HS in Jun-2022
mydf = comtradeapicall.getTarifflineDataBulkAvailability(subscription_key, typeCode='C', freqCode='M', clCode='HS',
                                                         period='202206', reporterCode=None)
mydf.head(5)
# Out:
#                                              fileUrl fileSize  reporterCode  \
# 0  https://comtradeapi.un.org/bulk/v1/fileTariffl...  3.73 MB           100
# 1  https://comtradeapi.un.org/bulk/v1/fileTariffl...  6.27 MB           124
# 2  https://comtradeapi.un.org/bulk/v1/fileTariffl...  1.17 MB           152
# 3  https://comtradeapi.un.org/bulk/v1/fileTariffl...  1.60 MB           191
# 4  https://comtradeapi.un.org/bulk/v1/fileTariffl...  6.17 MB           203
#
#   freqCode typeCode classificationCode  period partitionKey  \
# 0        M        C                 H6  202206          100
# 1        M        C                 H6  202206          124
# 2        M        C                 H6  202206          152
# 3        M        C                 H6  202206          191
# 4        M        C                 H6  202206          203
#
#                                               rowKey  \
# 0  26cfcd2bb0fc73452fa2e849c69e0fe210ae98067f6f8e...
# 1  55715f53ace4518405dff28296558882e95e21eac60776...
# 2  101bc3dede0e47f952dac636dec6ba8893f6999df518ad...
# 3  ba3b3881998307b7be59c75655ff9973d55d08cef2c6aa...
# 4  ec87e4dc6f8842c8a28b706efefb1c26c2528c953fe797...
#
#                            timestamp  \
# 0  2023-01-07T02:15:45.7550327+00:00
# 1  2022-09-13T02:23:38.3822657+00:00
# 2    2022-09-03T18:03:53.08535+00:00
# 3  2023-01-16T21:03:41.3625567+00:00
# 4  2022-08-21T08:21:58.7217539+00:00
#
#                                              eTag
# 0  W/"datetime'2023-01-07T02%3A15%3A45.7550327Z'"
# 1  W/"datetime'2022-09-13T02%3A23%3A38.3822657Z'"
# 2    W/"datetime'2022-09-03T18%3A03%3A53.08535Z'"
# 3  W/"datetime'2023-01-16T21%3A03%3A41.3625567Z'"
# 4  W/"datetime'2022-08-21T08%3A21%3A58.7217539Z'"

# %%
# list data availabity from last week for reference year 2021
mydf = comtradeapicall.getFinalDataAvailability(subscription_key, typeCode='C', freqCode='A', clCode='HS',
                                                period='2021', reporterCode=None, publishedDateFrom=lastweek, publishedDateTo=None)
mydf.head(5)
# Out:
#          datasetCode typeCode freqCode  period  reporterCode reporterISO  \
# 0  20222202101182100        C        A    2021           222         SLV
#
#   reporterDesc classificationCode classificationSearchCode  \
# 0  El Salvador                 H5                       HS
#
#    isOriginalClassification  isExtendedFlowCode  isExtendedPartnerCode  \
# 0                      True                True                   True
#
#    isExtendedPartner2Code  isExtendedCmdCode  isExtendedCustomsCode  \
# 0                   False               True                  False
#
#    isExtendedMotCode  totalRecords  datasetChecksum          firstReleased  \
# 0              False         98939        782827683  2022-02-01T15:56:35.4
#
#                   lastReleased
# 0  2023-01-30T14:11:50.7466667

# %%
# list tariffline data availabity from last week for reference period June 2022
mydf = comtradeapicall.getTarifflineDataAvailability(subscription_key, typeCode='C', freqCode='M',
                                                     clCode='HS',
                                                     period='202206', reporterCode=None, publishedDateFrom=lastweek, publishedDateTo=None)
mydf.head(5)
# Out:
#          datasetCode typeCode freqCode  period  reporterCode reporterISO  \
# 0  30068202206202100        C        M  202206            68         BOL
# 1  30222202206202100        C        M  202206           222         SLV
# 2  30268202206182100        C        M  202206           268         GEO
# 3  30600202206202100        C        M  202206           600         PRY
#
#   classificationCode  isOriginalClassification  isExtendedFlowCode  \
# 0                 H6                      True                True
# 1                 H6                      True               False
# 2                 H5                      True                True
# 3                 H6                      True               False
#
#    isExtendedPartnerCode  isExtendedPartner2Code  isExtendedCmdCode  \
# 0                   True                   False               True
# 1                   True                   False               True
# 2                   True                   False               True
# 3                   True                    True               True
#
#    isExtendedCustomsCode  isExtendedMotCode  totalRecords  datasetChecksum  \
# 0                  False               True         40374      -1038552479
# 1                  False              False         24383        648829595
# 2                  False               True         27716       1365265825
# 3                  False              False         22266       -876986026
#
#    lengthCmdCode                firstReleased                 lastReleased
# 0             10       2022-08-25T21:14:59.97  2023-02-01T06:55:43.0666667
# 1             10  2022-08-08T20:49:11.0566667  2023-01-31T18:52:06.2666667
# 2              6  2022-08-11T21:07:58.0333333  2023-01-27T03:39:14.0033333
# 3             11       2022-07-19T15:28:24.55  2023-01-26T21:46:46.5233333

# %%
# list bulk data availability for SITC Rev.1 for reference year 2021 released since last week
mydf = comtradeapicall.getFinalDataBulkAvailability(subscription_key, typeCode='C', freqCode='A',
                                                    clCode='S1',
                                                    period='2021', reporterCode=None, publishedDateFrom=lastweek, publishedDateTo=None)
mydf.head(5)
# Out:
#                                              fileUrl   fileSize  \
# 0  https://comtradeapi.un.org/bulk/v1/file/222/6c...  714.95 KB
#
#    isOriginalClassification  reporterCode freqCode typeCode  \
# 0                     False           222        A        C
#
#   classificationCode  refPeriodId  period       publicationDate partitionKey  \
# 0                 S1       202101    2021  2023-01-30T15:12:29Z          222
#
#                                               rowKey  \
# 0  6cf155c5a53c846057c030d49057b218793d9523389fef...
#
#                            timestamp  \
# 0  2023-01-30T14:12:29.7562734+00:00
#
#                                              eTag
# 0  W/"datetime'2023-01-30T14%3A12%3A29.7562734Z'"

# %%
# list classic annual bulk file availability released from yesterday
mydf = comtradeapicall.getFinalClassicDataBulkAvailability(subscription_key, typeCode='C', freqCode='A',
                                                           clCode='HS',
                                                           period=None, reporterCode=None, publishedDateFrom=lastweek, publishedDateTo=None)
mydf.head(5)
# Out:
#                                              fileUrl   fileSize  \
# 0  https://comtradeapi.un.org/bulk/v1/fileClassic...  962.84 KB
# 1  https://comtradeapi.un.org/bulk/v1/fileClassic...  783.08 KB
# 2  https://comtradeapi.un.org/bulk/v1/fileClassic...    2.18 MB
# 3  https://comtradeapi.un.org/bulk/v1/fileClassic...    2.17 MB
# 4  https://comtradeapi.un.org/bulk/v1/fileClassic...    3.14 MB
#
#    isOriginalClassification  reporterCode freqCode typeCode  \
# 0                      True           104        A        C
# 1                      True            28        A        C
# 2                      True           320        A        C
# 3                      True           404        A        C
# 4                      True           428        A        C
#
#   classificationCode  refPeriodId  period       publicationDate partitionKey  \
# 0                 H6       202301    2023  2024-03-14T05:41:55Z          104
# 1                 H3       202301    2023  2024-03-14T21:57:53Z           28
# 2                 H6       202301    2023  2024-03-19T02:20:53Z          320
# 3                 H5       202001    2020  2024-03-15T15:06:46Z          404
# 4                 H6       202301    2023  2024-03-19T03:43:42Z          428
#
#                                               rowKey  \
# 0  cfb2148e1c8e7f00e5582b567d4be52af4dcf68098f9c1...
# 1  5fc54929a57fb9a86618782cdf3cd837373ec3f33bba9e...
# 2  32986d51241cc1824d2ed301eea7db9a203300b1863e1a...
# 3  dadcc63f3e34c3ed035336267c5b36299f630f8ae1a7ee...
# 4  3e56287c41b7aa876ea66867555cc42526f37035689303...
#
#                            timestamp  \
# 0  2024-03-14T04:42:00.8869213+00:00
# 1   2024-03-14T20:57:59.041235+00:00
# 2  2024-03-19T01:21:09.5067679+00:00
# 3  2024-03-15T14:06:57.0084781+00:00
# 4  2024-03-19T02:43:55.9984626+00:00
#
#                                              eTag
# 0  W/"datetime'2024-03-14T04%3A42%3A00.8869213Z'"
# 1   W/"datetime'2024-03-14T20%3A57%3A59.041235Z'"
# 2  W/"datetime'2024-03-19T01%3A21%3A09.5067679Z'"
# 3  W/"datetime'2024-03-15T14%3A06%3A57.0084781Z'"
# 4  W/"datetime'2024-03-19T02%3A43%3A55.9984626Z'"

# %%
# list bulk tariffline data availability from last week for reference period June 2022
mydf = comtradeapicall.getTarifflineDataBulkAvailability(subscription_key, typeCode='C', freqCode='M',
                                                         clCode='HS',
                                                         period='202206', reporterCode=None, publishedDateFrom=lastweek, publishedDateTo=None)
mydf.head(5)
# Out:
#                                              fileUrl   fileSize  reporterCode  \
# 0  https://comtradeapi.un.org/bulk/v1/fileTariffl...  422.31 KB           222
# 1  https://comtradeapi.un.org/bulk/v1/fileTariffl...  476.36 KB           268
# 2  https://comtradeapi.un.org/bulk/v1/fileTariffl...  370.63 KB           600
# 3  https://comtradeapi.un.org/bulk/v1/fileTariffl...  538.95 KB            68
#
#   freqCode typeCode classificationCode  period partitionKey  \
# 0        M        C                 H6  202206          222
# 1        M        C                 H5  202206          268
# 2        M        C                 H6  202206          600
# 3        M        C                 H6  202206           68
#
#                                               rowKey  \
# 0  6a694b8b570f2292ca180679cd3397b5ecddc41fa94df4...
# 1  7345dcc7f7511016b04bde2c88c3548bd391ae2528871b...
# 2  6b8d62e9e984404b36a12f9333efadd62e55af9f119ca8...
# 3  5c0297485c1cc4390ce75f10d4fef112c7b39b2743bb8b...
#
#                            timestamp  \
# 0  2023-01-31T18:51:06.7572309+00:00
# 1   2023-01-27T03:38:48.571311+00:00
# 2  2023-01-26T21:46:07.7140418+00:00
# 3  2023-02-01T06:55:03.4177878+00:00
#
#                                              eTag
# 0  W/"datetime'2023-01-31T18%3A51%3A06.7572309Z'"
# 1   W/"datetime'2023-01-27T03%3A38%3A48.571311Z'"
# 2  W/"datetime'2023-01-26T21%3A46%3A07.7140418Z'"
# 3  W/"datetime'2023-02-01T06%3A55%3A03.4177878Z'"

# %%
# Call live update
mydf = comtradeapicall.getLiveUpdate(subscription_key)
mydf.head(5)
# Out:
#       size             startedAt           completedAt   status  \
# 0  1149698  2023-02-02 10:29:08Z  2023-02-02 10:29:04Z  Success
# 1   717285  2023-02-02 10:28:46Z  2023-02-02 10:28:40Z  Success
# 2   674722  2023-02-02 10:28:44Z  2023-02-02 10:28:40Z  Success
# 3   659351  2023-02-02 10:28:15Z  2023-02-02 10:28:13Z  Success
# 4   734310  2023-02-02 10:28:15Z  2023-02-02 10:28:13Z  Success
#
#                   lastUpdated                                queuedAt  \
# 0  Thursday, February 2, 2023  Thursday, February 2, 2023 11:29:02 AM
# 1  Thursday, February 2, 2023  Thursday, February 2, 2023 11:28:29 AM
# 2  Thursday, February 2, 2023  Thursday, February 2, 2023 11:28:30 AM
# 3  Thursday, February 2, 2023  Thursday, February 2, 2023 11:27:59 AM
# 4  Thursday, February 2, 2023  Thursday, February 2, 2023 11:27:54 AM
#
#   releaseStatus reporterCode freqCode typeCode classificationCode  period
# 0      Released          203        A        S              EB10S    2021
# 1      Released          203        A        S               EB10    2020
# 2      Released          203        A        S               EB02    2021
# 3      Released          203        A        S               EB02    2020
# 4      Released          203        A        S               EB10    2021

# %%
# Get metadata
mydf = comtradeapicall.getMetadata(subscription_key, typeCode='C', freqCode='M', clCode='HS', period='202205',
                                   reporterCode=None, showHistory=False)
mydf.head(5)
# Out:
#           datasetCode typeCode freqCode  period  reporterCode currency  \
# 0   30056202205202100        C        M  202205            56      EUR
# 2   30616202205202100        C        M  202205           616      USD
# 5   30688202205202100        C        M  202205           688      USD
# 9   30504202205202100        C        M  202205           504      MAD
# 10  30703202205202100        C        M  202205           703      EUR
#
#    importConvFactor exportConvFactor tradeSystem classificationCode  \
# 0           1.05785          1.05785     Special                 H6
# 2                 1                1     Special                 H6
# 5                 1                1     General                 H6
# 9          0.100004         0.100004     Special                 H6
# 10          1.05785          1.05785     Special                 H6
#
#    importValuation exportValuation              importPartnerCountry  \
# 0              CIF             FOB  Origin/Consignment for Intra EU
# 2              CIF             FOB                            Origin
# 5          CIF/FOB             FOB                            Origin
# 9              CIF             FOB                            Origin
# 10             CIF             FOB                            Origin
#
#       exportPartnerCountry importPartner2Country exportPartner2Country  \
# 0   Last Known Destination                   N/A                   N/A
# 2   Last Known Destination                   N/A                   N/A
# 5   Last Known Destination           Consignment                   N/A
# 9   Last Known Destination                   N/A                   N/A
# 10  Last Known Destination           Consignment                   N/A
#
#                                       publicationNote  \
# 0   Revised Data: Data for this period was publish...
# 2   Revised Data: Data for this period was publish...
# 5   Revised Data: Data for this period was publish...
# 9   New Data: Data for this period is published fo...
# 10  Revised Data: Data for this period was publish...
#
#             publicationDate publicationDateShort isLatestPublication
# 0   2022-10-29T07:18:34.403           29/10/2022                True
# 2   2022-11-28T09:46:48.283           28/11/2022                True
# 5    2022-11-28T13:19:51.57           28/11/2022                True
# 9       2022-12-21T21:12:15           21/12/2022                True
# 10   2022-12-22T12:29:11.81           22/12/2022                True

# %%
# Submit async request (final data)
myJson = comtradeapicall.submitAsyncFinalDataRequest(subscription_key, typeCode='C', freqCode='M', clCode='HS',
                                                     period='202205',
                                                     reporterCode='36', cmdCode='91,90', flowCode='M', partnerCode=None,
                                                     partner2Code=None,
                                                     customsCode=None, motCode=None, aggregateBy=None,
                                                     breakdownMode='classic')
print("requestID: ", myJson['requestId'])
# Out:
# Return message: Your request is accepted.You will be notified through your email when the data is ready for download
# requestID:  1167874f-bad1-4a8c-94e3-bbf670fd5a6f

# %%
# Submit async request (tariffline data)
myJson = comtradeapicall.submitAsyncTarifflineDataRequest(subscription_key, typeCode='C', freqCode='M',
                                                          clCode='HS',
                                                          period='202205',
                                                          reporterCode=None, cmdCode='91,90', flowCode='M',
                                                          partnerCode=None,
                                                          partner2Code=None,
                                                          customsCode=None, motCode=None)
print("requestID: ", myJson['requestId'])
# Out:
# Return message: Your request is accepted.You will be notified through your email when the data is ready for download
# requestID:  0ef78e21-b12b-4ae5-bd84-557dafa3bb8a

# %%
# check async status
# batchId = requestId
mydf = comtradeapicall.checkAsyncDataRequest(subscription_key,
                                             batchId='0ef78e21-b12b-4ae5-bd84-557dafa3bb8a')
print(mydf.iloc[0]['status'])
print(mydf.iloc[0]['uri'])
# Out:
# Completed
# https://comtradeapi.un.org/files/v1/async-downloads/batchid-91c5dd20-e827-4e58-a970-0a27a6c5fb54.zip

# %%
# check async status -- all batch history
mydf = comtradeapicall.checkAsyncDataRequest(subscription_key)
mydf

# %%
# submit async and download the result (final data)
comtradeapicall.downloadAsyncFinalDataRequest(subscription_key, directory, typeCode='C', freqCode='M',
                                              clCode='HS', period='202209', reporterCode=None, cmdCode='91,90',
                                              flowCode='M', partnerCode=None, partner2Code=None,
                                              customsCode=None, motCode=None)
# Out:
# Return message: Your request is accepted.You will be notified through your email when the data is ready for download
# Processing and downloading the result. BatchId:  8d2e7fe7-609b-48ec-aae5-94423991ae33
# Batch Status:  Submitted
# Batch Status:  Running
# Batch Status:  Completed
# batchid-1a26505b-b818-404d-9f16-06f78be16efd.zip  downloaded successfully

# %%
# submit async and download the result (tariffline)
comtradeapicall.downloadAsyncTarifflineDataRequest(subscription_key, directory, typeCode='C', freqCode='M',
                                                   clCode='HS', period='202209', reporterCode=None, cmdCode='91,90',
                                                   flowCode='M', partnerCode=None, partner2Code=None,
                                                   customsCode=None, motCode=None)
# Out:
# Return message: Your request is accepted.You will be notified through your email when the data is ready for download
# Processing and downloading the result. BatchId:  8803bec1-0f41-44ed-9c9f-eaf982036d26
# Batch Status:  Submitted
# Batch Status:  Running
# Batch Status:  Completed
# batchid-16dc58da-a818-45ad-a760-b62373d892fe.zip  downloaded successfully

# %%
# download the list of reference tables
mydf = comtradeapicall.listReference()
mydf.head(5)
# Out:
#    category              variable  \
# 0      freq             Frequency
# 1      flow            Trade Flow
# 2       mot    Mode of Transports
# 3   partner  Partner country/area
# 4  reporter              Reporter
#
#                                          description  \
# 0      The time interval at which observations occur
# 1  Trade flow or sub-flow (exports, re-exports, i...
# 2  The mode of transport used when goods enter or...
# 3  The partner country or geographic area for the...
# 4  The country or geographic area to which the me...
#
#                                              fileuri
# 0  https://comtradeapi.un.org/files/v1/app/refere...
# 1  https://comtradeapi.un.org/files/v1/app/refere...
# 2  https://comtradeapi.un.org/files/v1/app/refere...
# 3  https://comtradeapi.un.org/files/v1/app/refere...
# 4  https://comtradeapi.un.org/files/v1/app/refere...

# %%
# download the list of reference table of cmd:B5
mydf = comtradeapicall.listReference('cmd:B5')
mydf.head(5)
# Out:
#   category variable                                        description  \
# 8   cmd:B5  Product  The classification of BEC Rev.5 – goods or ser...
#
#                                              fileuri
# 8  https://comtradeapi.un.org/files/v1/app/refere...

# %%
# download specific reference (list available at listReference())
mydf = comtradeapicall.getReference('reporter')
mydf.head(5)
# Out:
#    id         text  reporterCode reporterDesc reporterNote  \
# 0   4  Afghanistan             4  Afghanistan  Afghanistan
# 1   8      Albania             8      Albania      Albania
# 2  12      Algeria            12      Algeria      Algeria
# 3  20      Andorra            20      Andorra      Andorra
# 4  24       Angola            24       Angola       Angola
#
#   reporterCodeIsoAlpha2 reporterCodeIsoAlpha3   entryEffectiveDate  isGroup  \
# 0                    AF                   AFG  1900-01-01T00:00:00    False
# 1                    AL                   ALB  1900-01-01T00:00:00    False
# 2                    DZ                   DZA  1900-01-01T00:00:00    False
# 3                    AD                   AND  1900-01-01T00:00:00    False
# 4                    AO                   AGO  1900-01-01T00:00:00    False
#
#   entryExpiredDate
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
# download specific reference (list available at listReference())
mydf = comtradeapicall.getReference('customs')
mydf.head(5)
# Out:
#     id                             text
# 0  all                              All
# 1  C00    TOTAL customs procedure codes
# 2  C01           Clearance for home use
# 3  C02  Reimportation in the same state
# 4  C03             Outright exportation

# %%
# Convert country/area ISO3 to Comtrade code
country_code = comtradeapicall.convertCountryIso3ToCode('USA,FRA,CHE,ITA')
print(country_code)
# Out:
# 251,380,250,756,757,840,842,841

# %%
# use the convert function country_code in preview call
mydf = comtradeapicall.previewFinalData(typeCode='C', freqCode='M', clCode='HS', period='202205',
                                        reporterCode=comtradeapicall.convertCountryIso3ToCode('USA,FRA,CHE,ITA'), cmdCode='91', flowCode='M', partnerCode=None,
                                        partner2Code=None, customsCode=None, motCode=None)
mydf
# Out:
#     typeCode freqCode  refPeriodId  refYear  refMonth  period  reporterCode  \
# 0          C        M     20220501     2022         5  202205           251
# 1          C        M     20220501     2022         5  202205           251
# 2          C        M     20220501     2022         5  202205           251
# 3          C        M     20220501     2022         5  202205           251
# 4          C        M     20220501     2022         5  202205           251
# ..       ...      ...          ...      ...       ...     ...           ...
# 495        C        M     20220501     2022         5  202205           757
# 496        C        M     20220501     2022         5  202205           757
# 497        C        M     20220501     2022         5  202205           757
# 498        C        M     20220501     2022         5  202205           757
# 499        C        M     20220501     2022         5  202205           757
#
#     reporterISO reporterDesc flowCode  ... netWgt  isNetWgtEstimated grossWgt  \
# 0          None         None        M  ...    0.0              False      0.0
# 1          None         None        M  ...    0.0               True      0.0
# 2          None         None        M  ...    0.0               True      0.0
# 3          None         None        M  ...    0.0               True      0.0
# 4          None         None        M  ...    0.0               True      0.0
# ..          ...          ...      ...  ...    ...                ...      ...
# 495        None         None        M  ...    0.0               True      0.0
# 496        None         None        M  ...    0.0               True      0.0
# 497        None         None        M  ...    0.0               True      0.0
# 498        None         None        M  ...    0.0               True      0.0
# 499        None         None        M  ...    0.0               True      0.0
#
#     isGrossWgtEstimated     cifvalue fobvalue primaryValue  \
# 0                 False       62.413     None       62.413
# 1                 False  7282892.093     None  7282892.093
# 2                 False      606.148     None      606.148
# 3                 False  1233922.785     None  1233922.785
# 4                 False      439.008     None      439.008
# ..                  ...          ...      ...          ...
# 495               False    20021.627     None    20021.627
# 496               False  1090718.590     None  1090718.590
# 497               False   263579.325     None   263579.325
# 498               False   430491.509     None   430491.509
# 499               False  2459016.139     None  2459016.139
#
#     legacyEstimationFlag isReported  isAggregate
# 0                      0      False         True
# 1                      4      False         True
# 2                      4      False         True
# 3                      4      False         True
# 4                      4      False         True
# ..                   ...        ...          ...
# 495                    4      False         True
# 496                    4      False         True
# 497                    4      False         True
# 498                    4      False         True
# 499                    4      False         True
#
# [500 rows x 47 columns]

# %%
# Get the Standard unit value (qtyUnitCode 8 [kg]) for commodity 010391 in 2022
mydf = comtradeapicall.getSUV(subscription_key,
                              period='2022', cmdCode='010391', flowCode=None, qtyUnitCode=8)
mydf
# Out:
#   typeCode freqCode period flowCode classificationCode cmdCode  qtyUnitCode  \
# 0        C        A   2022        M                 HS  010391            8
# 1        C        A   2022        X                 HS  010391            8
#
#   qtyUnitAbbr     uvMin       suv     uvMax  isUniModalDistribution
# 0          kg  1.003640  2.262739  5.424094                    True
# 1          kg  0.953742  2.309527  5.955193                    True

# %%
# Get and compare data in bilateral layout (reported data is complemented by mirror partner data)
mydf = comtradeapicall.getBilateralData(subscription_key, typeCode='C', freqCode='M', clCode='HS', period='202205',
                                        reporterCode='36', cmdCode='TOTAL', flowCode='X', partnerCode=None)
mydf
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 2
#       1 # Get and compare data in bilateral layout (reported data is complemented by mirror partner data)
# ----> 2 mydf = comtradeapicall.getBilateralData(subscription_key, typeCode='C', freqCode='M', clCode='HS', period='202205',
#       3                                         reporterCode='36', cmdCode='TOTAL', flowCode='X', partnerCode=None)
#       4 mydf
#
# AttributeError: module 'comtradeapicall' has no attribute 'getBilateralData'

# %%
# Get data in trade balance layout (exports and imports next to each other)
mydf = comtradeapicall.getTradeBalance(subscription_key, typeCode='C', freqCode='M', clCode='HS', period='202205',
                                       reporterCode='36', cmdCode='TOTAL', partnerCode=None)
mydf
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 2
#       1 # Get data in trade balance layout (exports and imports next to each other)
# ----> 2 mydf = comtradeapicall.getTradeBalance(subscription_key, typeCode='C', freqCode='M', clCode='HS', period='202205',
#       3                                        reporterCode='36', cmdCode='TOTAL', partnerCode=None)
#       4 mydf
#
# AttributeError: module 'comtradeapicall' has no attribute 'getTradeBalance'

# %%
# Count of numbers of records (without key - single period)
mydf = comtradeapicall.previewCountFinalData(typeCode='C', freqCode='M', clCode='HS', period='202201', reporterCode='', cmdCode='9*',
                                             flowCode='M', partnerCode='0,826', partner2Code=None, customsCode=None, motCode=None, aggregateBy=None, breakdownMode='classic')
mydf
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 2
#       1 # Count of numbers of records (without key - single period)
# ----> 2 mydf = comtradeapicall.previewCountFinalData(typeCode='C', freqCode='M', clCode='HS', period='202201', reporterCode='', cmdCode='9*',
#       3                                              flowCode='M', partnerCode='0,826', partner2Code=None, customsCode=None, motCode=None, aggregateBy=None, breakdownMode='classic')
#       4 mydf
#
# AttributeError: module 'comtradeapicall' has no attribute 'previewCountFinalData'

# %%
# Count of numbers of records (using subscription - multiple periods)
mydf = comtradeapicall.getCountFinalData(subscription_key, typeCode='C', freqCode='M', clCode='HS', period='202201,202202', reporterCode='',
                                         cmdCode='9*', flowCode='M', partnerCode='0,826', partner2Code=None, customsCode=None, motCode=None, aggregateBy=None, breakdownMode='classic')
mydf
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Count of numbers of records (using subscription - multiple periods)
# ----> 2 mydf = comtradeapicall.getCountFinalData(subscription_key, typeCode='C', freqCode='M', clCode='HS', period='202201,202202', reporterCode='',
#       3                                          cmdCode='9*', flowCode='M', partnerCode='0,826', partner2Code=None, customsCode=None, motCode=None, aggregateBy=None, breakdownMode='classic')
#       4 mydf
#
# AttributeError: module 'comtradeapicall' has no attribute 'getCountFinalData'
